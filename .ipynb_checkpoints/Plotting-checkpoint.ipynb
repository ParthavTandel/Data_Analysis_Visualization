# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot as plt
data = pd.read_csv("reviews.csv", parse_dates = ["Timestamp"])
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %%
data["Day"] = data["Timestamp"].dt.date
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment         Day
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021-04-02
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021-04-02

# %%
day_average = data.groupby(["Day"]).mean()
plt.figure(figsize=(25,3))
plt.plot(day_average.index, day_average["Rating"])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\3043806831.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day_average = data.groupby(["Day"]).mean()

# %%
data["Week"] = data["Timestamp"].dt.strftime("%Y %U")
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment         Day     Week
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02  2021 13
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021-04-02  2021 13
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021-04-02  2021 13

# %%
week_average = data.groupby(["Week"]).mean()
plt.figure(figsize=(25,3))
plt.plot(week_average.index, week_average["Rating"])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\1771326116.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   week_average = data.groupby(["Week"]).mean()

# %%
data["Month"] = data["Timestamp"].dt.strftime("%Y %m")
month_average = data.groupby(["Month"]).mean()
plt.figure(figsize=(25,3))
plt.plot(month_average.index, month_average["Rating"])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\2482224717.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   month_average = data.groupby(["Month"]).mean()

# %%
data["Month"] = data["Timestamp"].dt.strftime("%Y %m")
month_average_crs = data.groupby(["Month","Course Name"]).mean().unstack()
month_average_crs.plot(figsize=(25,8))
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\58003625.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   month_average_crs = data.groupby(["Month","Course Name"]).mean().unstack()
# <AxesSubplot: xlabel='Month'>

# %%
data["Month"] = data["Timestamp"].dt.strftime("%Y %m")
month_average_crs = data.groupby(["Month","Course Name"])["Rating"].count().unstack()
month_average_crs.plot(figsize=(25,8))
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
data["Weekday"] = data["Timestamp"].dt.strftime("%A")
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment         Day     Week    Month  \
# 0 2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1 2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 2 2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 3 2021-04-02 03:33:24+00:00     5.0     NaN  2021-04-02  2021 13  2021 04
# 4 2021-04-02 03:31:49+00:00     4.5     NaN  2021-04-02  2021 13  2021 04
#
#   Weekday
# 0  Friday
# 1  Friday
# 2  Friday
# 3  Friday
# 4  Friday

# %%
weekday_average = data.groupby(["Weekday"]).mean()
plt.figure(figsize=(10,5))
plt.plot(weekday_average.index, weekday_average["Rating"])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\2324488483.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   weekday_average = data.groupby(["Weekday"]).mean()

# %%
data["Daynumber"] = data["Timestamp"].dt.strftime("%w")
weekday_average = data.groupby(["Weekday", "Daynumber"]).mean()
weekday_average = weekday_average.sort_values("Daynumber")
weekday_average.index.get_level_values(0)
plt.figure(figsize=(10,5))
plt.plot(weekday_average.index.get_level_values(0), weekday_average["Rating"])
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_2596\282977802.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   weekday_average = data.groupby(["Weekday", "Daynumber"]).mean()
